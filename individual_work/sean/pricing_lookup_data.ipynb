# %%
# Import Dependencies
import pandas as pd
import json

# %% [markdown]
# ### **Import and Display CSV**

# %%
# Filepath
csv_filepath =  "../../data/processed/cleaned_listings.csv"

# Read CSV
listings_csv = pd.read_csv(csv_filepath)

listings_csv
# Out:
#                        id   latitude  longitude  downtown_distance  \
# 0      696407278180533419  43.670920 -79.395190           3.215592
# 1      696457318817239920  43.655704 -79.399910           1.784751
# 2      696602542310304703  43.648778 -79.401183           1.325140
# 3      696973520016945803  43.612110 -79.539850          12.753377
# 4      697004718610327555  43.735735 -79.480703          12.802003
# ...                   ...        ...        ...                ...
# 9609  1355385238383046824  43.645749 -79.393083           0.595242
# 9610  1362331480938692703  43.649540 -79.388640           0.781578
# 9611  1363197896119450651  43.653270 -79.396790           1.419694
# 9612  1364280421231205552  43.705119 -79.272289          11.558048
# 9613  1364983907816625847  43.655243 -79.406150           2.079848
#
#      downtown_zone                      neighbourhood  neighbourhood_freq  \
# 0         Downtown                              Annex                 288
# 1      City Center               Kensington-Chinatown                 219
# 2      City Center               Kensington-Chinatown                 219
# 3       Outer City                          Alderwood                  37
# 4       Outer City               Downsview-Roding-CFB                  80
# ...            ...                                ...                 ...
# 9609   City Center  Waterfront Communities-The Island                1730
# 9610   City Center  Waterfront Communities-The Island                1730
# 9611   City Center               Kensington-Chinatown                 219
# 9612    Outer City                Clairlea-Birchmount                  51
# 9613      Downtown               Kensington-Chinatown                 219
#
#       luxury_neighborhood_flag        room_type property_type  ...  \
# 0                            0  Entire home/apt         condo  ...
# 1                            0     Private room   rental unit  ...
# 2                            0  Entire home/apt   rental unit  ...
# 3                            0  Entire home/apt   rental unit  ...
# 4                            0  Entire home/apt     townhouse  ...
# ...                        ...              ...           ...  ...
# 9609                         1  Entire home/apt   rental unit  ...
# 9610                         1  Entire home/apt          home  ...
# 9611                         0  Entire home/apt          home  ...
# 9612                         0     Private room          home  ...
# 9613                         0     Private room          home  ...
#
#      bathrooms_count                                          amenities  \
# 0                1.0  ["Hair dryer", "Central heating", "Paid parkin...
# 1                1.0  ["Hair dryer", "Central heating", "Shampoo", "...
# 2                1.0  ["Hair dryer", "Room-darkening shades", "Keypa...
# 3                1.0  ["Hair dryer", "Heating", "Shampoo", "Body soa...
# 4                2.5  ["Room-darkening shades", "Keypad", "Elevator"...
# ...              ...                                                ...
# 9609             1.0  ["Hair dryer", "Elevator", "Central heating", ...
# 9610             1.0  ["Hair dryer", "Cleaning available during stay...
# 9611             1.0  ["Hair dryer", "Keypad", "Mini fridge", "Heati...
# 9612             2.0  ["Hair dryer", "Room-darkening shades", "Firep...
# 9613             2.0  ["Dedicated workspace", "Fire extinguisher", "...
#
#         min_stay  allow_long_term  price  number_of_reviews_ly  \
# 0     Short-term                0  450.0                     2
# 1     Short-term                0   78.0                     2
# 2     Short-term                0  132.0                     4
# 3     Short-term                0   81.0                    12
# 4     Short-term                0  236.0                    15
# ...          ...              ...    ...                   ...
# 9609  Short-term                0  170.0                     0
# 9610  Short-term                0  145.0                     0
# 9611  Short-term                0  114.0                     0
# 9612  Short-term                1   55.0                     0
# 9613  Short-term                0   95.0                     0
#
#       host_is_superhost host_listings_count  estimated_occupancy_l365d  \
# 0                     0                   7                         56
# 1                     1                   8                        112
# 2                     1                   1                        224
# 3                     0                   1                         60
# 4                     0                   1                         90
# ...                 ...                 ...                        ...
# 9609                  1                   1                         24
# 9610                  0                   1                          6
# 9611                  1                   5                          6
# 9612                  0                   2                          6
# 9613                  1                   4                          6
#
#      estimated_revenue_l365d
# 0                    25200.0
# 1                     8736.0
# 2                    29568.0
# 3                     4860.0
# 4                    21240.0
# ...                      ...
# 9609                  4080.0
# 9610                   870.0
# 9611                   684.0
# 9612                   330.0
# 9613                   570.0
#
# [9614 rows x 28 columns]

# %% [markdown]
# ### **Calculate Lookup Values**

# %%
# Filter by neighbourhood, property_type, room_type 
counts = listings_csv.groupby(['neighbourhood', 'property_type', 'room_type']).size().reset_index(name='count')

# Merge back into database
listing_base_categories = listings_csv.merge(counts,on=['neighbourhood', 'property_type', 'room_type'])

# Limit to those with counts over 10
filtered_base_categories = listing_base_categories[listing_base_categories['count']>=10]

# %%
# Calculate lower baseline values
neighbourhood_min_baseline = filtered_base_categories.groupby(['neighbourhood', 'room_type', 'property_type'])['price'].quantile(0.10).reset_index()

global_min_baseline = listing_base_categories.groupby(['room_type', 'property_type'])['price'].quantile(0.10).reset_index()

# %%
# Define output Dictionary
lookup_dict = {}

# Build Neighbourhood Database
for index, row in neighbourhood_min_baseline.iterrows():
    neighbourhood = row['neighbourhood']
    key = f"{row['room_type']}|{row['property_type']}"
    adjusted_price = round(row['price'] * 0.9, 2)          # setting baseline to 10% less than lowest 10 quartile as to not affect the prediction Model
    
    if neighbourhood not in lookup_dict:
        lookup_dict[neighbourhood] = {}
    lookup_dict[neighbourhood][key] = adjusted_price


# Fill missing counts
for _, row in global_min_baseline.iterrows():
    global_key = f"{row['room_type']}|{row['property_type']}"
    adjusted_price = round(row['price'] * 0.9, 2)
    
    for neighbourhood in listing_base_categories['neighbourhood'].unique():
        if neighbourhood not in lookup_dict:
            lookup_dict[neighbourhood] = {}
        
        if global_key not in lookup_dict[neighbourhood]:
            lookup_dict[neighbourhood][global_key] = adjusted_price

# %% [markdown]
# ### **Check and Verify price lookup Dict**

# %%
lookup_dict
# Out:
# {'Agincourt North': {'Private room|home': 35.1,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Agincourt South-Malvern West': {'Private room|home': 31.5,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Annex': {'Entire home/apt|condo': 87.75,
#   'Entire home/apt|home': 82.08,
#   'Entire home/apt|rental unit': 72.0,
#   'Private room|home': 42.57,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Bathurst Manor': {'Entire home/apt|home': 80.37,
#   'Private room|home': 42.75,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Bay Street Corridor': {'Entire home/apt|condo': 80.1,
#   'Entire home/apt|rental unit': 122.4,
#   'Private room|condo': 70.11,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Bayview Village': {'Entire home/apt|home': 116.19,
#   'Private room|home': 27.27,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Bayview Woods-Steeles': {'Private room|home': 38.61,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Bedford Park-Nortown': {'Entire home/apt|home': 90.0,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Birchcliffe-Cliffside': {'Entire home/apt|home': 71.64,
#   'Private room|home': 28.8,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Black Creek': {'Private room|home': 51.3,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Briar Hill-Belgravia': {'Private room|home': 37.98,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Cabbagetown-South St.James Town': {'Entire home/apt|home': 171.18,
#   'Entire home/apt|rental unit': 79.92,
#   'Private room|home': 47.25,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Caledonia-Fairbank': {'Entire home/apt|home': 68.94,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Church-Yonge Corridor': {'Entire home/apt|condo': 77.67,
#   'Entire home/apt|home': 83.97,
#   'Entire home/apt|rental unit': 67.68,
#   'Private room|condo': 67.68,
#   'Private room|home': 39.6,
#   'Private room|rental unit': 55.62,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Clairlea-Birchmount': {'Entire home/apt|home': 64.8,
#   'Private room|home': 33.12,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Clanton Park': {'Entire home/apt|home': 78.66,
#   'Private room|home': 40.14,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Cliffcrest': {'Entire home/apt|home': 86.76,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Corso Italia-Davenport': {'Entire home/apt|home': 56.43,
#   'Entire home/apt|rental unit': 58.05,
#   'Private room|home': 24.39,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Danforth': {'Entire home/apt|home': 115.2,
#   'Private room|home': 29.7,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Danforth East York': {'Entire home/apt|home': 74.52,
#   'Private room|home': 36.9,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Don Valley Village': {'Private room|home': 31.59,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Dovercourt-Wallace Emerson-Junction': {'Entire home/apt|guest suite': 58.5,
#   'Entire home/apt|home': 71.46,
#   'Entire home/apt|rental unit': 54.0,
#   'Private room|home': 41.4,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Downsview-Roding-CFB': {'Entire home/apt|home': 135.0,
#   'Private room|home': 31.5,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Dufferin Grove': {'Entire home/apt|home': 49.5,
#   'Entire home/apt|rental unit': 59.94,
#   'Private room|home': 62.46,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'East End-Danforth': {'Entire home/apt|guest suite': 55.8,
#   'Entire home/apt|home': 73.08,
#   'Entire home/apt|rental unit': 54.36,
#   'Private room|home': 53.19,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Edenbridge-Humber Valley': {'Private room|home': 21.42,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Eglinton East': {'Private room|home': 38.61,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Eringate-Centennial-West Deane': {'Private room|home': 64.98,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Etobicoke West Mall': {'Entire home/apt|condo': 114.3,
#   'Private room|home': 33.3,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Glenfield-Jane Heights': {'Private room|home': 41.94,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Greenwood-Coxwell': {'Entire home/apt|home': 92.25,
#   'Entire home/apt|rental unit': 72.36,
#   'Private room|home': 51.3,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Guildwood': {'Private room|home': 45.0,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'High Park North': {'Entire home/apt|home': 78.66,
#   'Entire home/apt|rental unit': 62.1,
#   'Private room|home': 36.9,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'High Park-Swansea': {'Entire home/apt|guest suite': 90.0,
#   'Entire home/apt|home': 90.0,
#   'Entire home/apt|rental unit': 63.54,
#   'Private room|home': 31.86,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Highland Creek': {'Private room|home': 30.78,
#   'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
# ...
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Forest Hill North': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Yonge-St.Clair': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Markland Wood': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Princess-Rosethorn': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Mount Dennis': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Brookhaven-Amesbury': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Kingsway South': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Henry Farm': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Mount Olive-Silverstone-Jamestown': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Rustic': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6},
#  'Elms-Old Rexdale': {'Entire home/apt|aparthotel': 240.3,
#   'Entire home/apt|bungalow': 76.5,
#   'Entire home/apt|cave': 55.8,
#   'Entire home/apt|condo': 82.8,
#   'Entire home/apt|cottage': 236.88,
#   'Entire home/apt|farm stay': 54.0,
#   'Entire home/apt|guest suite': 63.0,
#   'Entire home/apt|guesthouse': 72.0,
#   'Entire home/apt|home': 73.8,
#   'Entire home/apt|island': 178.2,
#   'Entire home/apt|loft': 97.29,
#   'Entire home/apt|place': 102.96,
#   'Entire home/apt|rental unit': 70.2,
#   'Entire home/apt|serviced apartment': 85.86,
#   'Entire home/apt|shipping container': 409.5,
#   'Entire home/apt|tiny home': 43.2,
#   'Entire home/apt|townhouse': 95.76,
#   'Entire home/apt|vacation home': 92.52,
#   'Entire home/apt|villa': 408.42,
#   'Private room|barn': 70.2,
#   'Private room|bed and breakfast': 50.58,
#   'Private room|boutique hotel': 148.14,
#   'Private room|bungalow': 37.8,
#   'Private room|casa particular': 32.22,
#   'Private room|condo': 45.9,
#   'Private room|cottage': 108.9,
#   'Private room|guest suite': 36.99,
#   'Private room|guesthouse': 55.8,
#   'Private room|home': 35.1,
#   'Private room|hostel': 81.9,
#   'Private room|hotel': 120.42,
#   'Private room|loft': 76.32,
#   'Private room|private room': 54.9,
#   'Private room|rental unit': 38.7,
#   'Private room|serviced apartment': 41.58,
#   'Private room|tiny home': 31.68,
#   'Private room|townhouse': 39.69,
#   'Private room|villa': 30.6}}

# %%
# Save the Price Lookup JSON
with open('../../results/baseline_pricing.json', 'w') as f:
    json.dump(lookup_dict, f, indent=2)
